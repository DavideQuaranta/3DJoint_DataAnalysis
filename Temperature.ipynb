# %%
import numpy as np
import matplotlib.pyplot as plt
import math as m
import pandas as pd
from scipy.optimize import curve_fit
from IPython.display import display, Math
from google.colab import drive

# %%
# # Definition of the path to take the data # #

#Execute these lines or use the menu bar on the left hand side (they're equivalent)
drive.mount('/content/drive', force_remount=True)
# For the code to run, the folder with the data (at least the shortcut) must be in the MyDrive directory
path = "/content/drive/MyDrive/3DJoint/data/"
# Out:
# Mounted at /content/drive

# %%
def convert(times):
  converted = []
  for i in range(len(times)):
    hours = int(data['time'].values[i][0:2])
    minutes = int(data['time'].values[i][3:5])
    seconds = int(data['time'].values[i][6:8])
    converted.append(seconds + 60*minutes + 60*60*hours)
  return converted

# %%
data1 = pd.read_excel(path+"TvsTime_1.xlsx")
data2 = pd.read_excel(path+"TvsTime_2.xlsx")
timesec1 = np.array(convert(data1['time']))
timesec2 = np.array(convert(data2['time']))
shift = timesec2[0] - timesec1[-1]
timesec_s = timesec2-shift
timesec = np.concatenate((timesec1, timesec_s))

# %%
data = pd.concat([data1,data2],ignore_index=True)
plt.plot(data['time'], data['T'])

# %%
plt.plot(timesec, data['T'])

# %%
data2
# Out:
#     Unnamed: 0      time      T
# 0            0  12:05:39  27.10
# 1            1  12:18:02  29.19
# 2            2  12:22:51  30.65
# 3            3  12:24:38  31.32
# 4            4  12:27:10  32.18
# 5            5  12:29:15  32.85
# 6            6  12:30:48  33.35
# 7            7  12:36:53  35.47
# 8            8  12:38:57  36.27
# 9            9  12:40:39  37.98
# 10          10  12:41:29  37.34
# 11          11  12:41:55  37.52
# 12          12  12:43:16  38.10
# 13          13  12:45:31  39.10
# 14          14  12:47:13  39.91
# 15          15  12:49:40  41.10
# 16          16  12:50:44  41.62
# 17          17  12:57:07  44.75
# 18          18  13:00:36  46.44
# 19          19  13:02:32  47.43
# 20          20  13:04:05  48.21
# 21          21  13:06:16  49.33
# 22          22  13:10:56  51.68
# 23          23  13:15:46  53.98
# 24          24  13:18:10  55.90
# 25          25  13:21:09  56.44
# 26          26  13:23:50  57.63
# 27          27  13:26:27  58.75
# ...
